# %%
import pandas as pd
import plotly_express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import base64
import requests

# %%
df = pd.read_csv('data/shopping_trends.csv')
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
print(f'Número de culunas: {df.shape[1]}')
print(f'Número de culunas: {df.shape[0]}')
# Out:
# Número de culunas: 19
# Número de culunas: 3900

# %%
# Renomeando colunas do dataset
df.columns = [
'ID_do_cliente',
'Idade', 
'Gênero', 
'Item_comprado', 
'Categoria', 
'Valor_da_compra_(USD)', 
'Localização', 
'Tamanho', 
'Cor', 
'Temporada', 
'Avaliação_da_avaliação', 
'Status_da_assinatura', 
'Método_de_pagamento', 
'Tipo_de_envio', 
'Desconto_aplicado', 
'Código_promocional_usado', 
'Compras_Anteriores', 
'Método_de_pagamento_preferido', 
'Frequência_de_compras'
]

#salvando dataframe com as colunas portugues
# df.to_csv('/home/black_d/Downloads/Dash_Bourds_Python/td_de_compras/DataFrames', index=False)


# Visualizando resultado
df.head(10)
# Out:
#    ID_do_cliente  Idade Gênero Item_comprado    Categoria  \
# 0              1     55   Male        Blouse     Clothing
# 1              2     19   Male       Sweater     Clothing
# 2              3     50   Male         Jeans     Clothing
# 3              4     21   Male       Sandals     Footwear
# 4              5     45   Male        Blouse     Clothing
# 5              6     46   Male      Sneakers     Footwear
# 6              7     63   Male         Shirt     Clothing
# 7              8     27   Male        Shorts     Clothing
# 8              9     26   Male          Coat    Outerwear
# 9             10     57   Male       Handbag  Accessories
#
#    Valor_da_compra_(USD)    Localização Tamanho        Cor Temporada  \
# 0                     53       Kentucky       L       Gray    Winter
# 1                     64          Maine       L     Maroon    Winter
# 2                     73  Massachusetts       S     Maroon    Spring
# ...

# %%
df['Tipo_de_envio'].value_counts()
# Out:
# Tipo_de_envio
# Free Shipping     675
# Standard          654
# Store Pickup      650
# Next Day Air      648
# Express           646
# 2-Day Shipping    627
# Name: count, dtype: int64

# %%
# Relação das Vendas por Tamanho e Temporadas
tamanho_por_temporada = df.groupby(['Temporada', 'Tamanho'])['Valor_da_compra_(USD)'].size().reset_index()
tamanho_por_temporada
# Out:
#    Temporada Tamanho  Valor_da_compra_(USD)
# 0       Fall       L                    260
# 1       Fall       M                    439
# 2       Fall       S                    172
# 3       Fall      XL                    104
# 4     Spring       L                    256
# 5     Spring       M                    452
# 6     Spring       S                    179
# 7     Spring      XL                    112
# 8     Summer       L                    257
# 9     Summer       M                    445
# 10    Summer       S                    160
# 11    Summer      XL                     93
# 12    Winter       L                    280
# 13    Winter       M                    419
# 14    Winter       S                    152
# 15    Winter      XL                    120

# %%
df.isnull().sum()
# Out:
# ID_do_cliente                    0
# Idade                            0
# Gênero                           0
# Item_comprado                    0
# Categoria                        0
# Valor_da_compra_(USD)            0
# Localização                      0
# Tamanho                          0
# Cor                              0
# Temporada                        0
# Avaliação_da_avaliação           0
# Status_da_assinatura             0
# Método_de_pagamento              0
# Tipo_de_envio                    0
# Desconto_aplicado                0
# Código_promocional_usado         0
# Compras_Anteriores               0
# Método_de_pagamento_preferido    0
# Frequência_de_compras            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID_do_cliente                  3900 non-null   int64
#  1   Idade                          3900 non-null   int64
#  2   Gênero                         3900 non-null   object
#  3   Item_comprado                  3900 non-null   object
#  4   Categoria                      3900 non-null   object
#  5   Valor_da_compra_(USD)          3900 non-null   int64
#  6   Localização                    3900 non-null   object
#  7   Tamanho                        3900 non-null   object
#  8   Cor                            3900 non-null   object
#  9   Temporada                      3900 non-null   object
#  10  Avaliação_da_avaliação         3900 non-null   float64
#  11  Status_da_assinatura           3900 non-null   object
# ...

# %%
df.describe()
# Out:
#        ID_do_cliente        Idade  Valor_da_compra_(USD)  \
# count    3900.000000  3900.000000            3900.000000
# mean     1950.500000    44.068462              59.764359
# std      1125.977353    15.207589              23.685392
# min         1.000000    18.000000              20.000000
# 25%       975.750000    31.000000              39.000000
# 50%      1950.500000    44.000000              60.000000
# 75%      2925.250000    57.000000              81.000000
# max      3900.000000    70.000000             100.000000
#
#        Avaliação_da_avaliação  Compras_Anteriores
# count             3900.000000         3900.000000
# mean                 3.749949           25.351538
# std                  0.716223           14.447125
# min                  2.500000            1.000000
# 25%                  3.100000           13.000000
# 50%                  3.700000           25.000000
# 75%                  4.400000           38.000000
# ...

# %% [markdown]
# ### Uma vez que ja conhecemos os dados e suas dimenções.<br>vamos resdponer essas perguntas:
# #### 1. Perfil do cliente
# * Qual é a faixa etária predominante dos nossos clientes?
# * Quais regiões possuem mais consumidores ativos?
# * Existe uma relação entre a localização e o tamanho do item comprado (por exemplo, tamanhos maiores vendidos em regiões específicas)?
# * Qual é a frequência de compras mais comum entre os clientes?
# #### 2. Vendas e performance de produtos
# * Quais categorias de produtos (ex.: roupas, calçados, acessórios) geram mais receita?
# * Qual é o item mais vendido em cada temporada?
# * Existem categorias ou itens com baixa avaliação que precisam de atenção?
# * Quais cores de produtos são mais populares em cada temporada?
# * Qual é o ticket médio das compras por método de pagamento?
# #### 3. Sazonalidade
# * Quais categorias de produtos têm maior demanda em cada temporada (ex.: verão, inverno)?
# * As cores dos itens variam conforme a estação?
# * Existe uma sazonalidade nas avaliações (ex.: avaliações mais baixas em alguma temporada específica)?
# #### 4. Métodos de pagamento e descontos
# * Qual é o método de pagamento mais utilizado pelos clientes?
# * Clientes que utilizam descontos têm maior frequência de compras?
# * Existe alguma preferência por método de pagamento dependendo da localização ou categoria do produto?

# %% [markdown]
# ## Perfil Cliente

# %% [markdown]
# #### Qual é a faixa etária predominante dos nossos clientes?

# %%
idade = df['Idade']
df_idade = idade.value_counts(ascending = False).reset_index()
df_idade.columns = ['Idade', 'Quantidade_Clientes']

#salvando tabela
# df_idade.to_csv('/home/black_d/Downloads/Dash_Bourds_Python/tendências_de_compras/DataFrames/df_idade.csv', index=False)
df_idade.head(11)
# Out:
#     Idade  Quantidade_Clientes
# 0      69                   88
# 1      57                   87
# 2      41                   86
# 3      25                   85
# 4      49                   84
# 5      50                   83
# 6      54                   83
# 7      27                   83
# 8      62                   83
# 9      32                   82
# 10     19                   81

# %%
# Ordenar e selecionar as 10 primeiras idades
df_idad = df_idade.head(10).sort_values(by='Quantidade_Clientes', ascending=False)
df_idade_str = df_idad
df_idade_str['Idade'] = df_idade['Idade'].astype(str)


# Criar o gráfico de barras
fig1 = px.bar(
    df_idade_str, 
    x='Quantidade_Clientes', 
    y='Idade', 
    title='Distribuição de Idade vs Quantidade',
    color='Idade',  # Coloração com base na quantidade
    # color_continuous_scale='Viridis',  # Paleta de cores
    orientation='h'
)

# Configurar layout
fig1.update_layout(
    showlegend = False, 
    title_x=0.5,  # Centralizar título
    # coloraxis_showscale=False,  # Remove a legenda da barra de cores
    # xaxis_title="Idade",  # Nome do eixo X
    # yaxis_title="Quantidade de Clientes",  # Nome do eixo Y
    bargap=0.1,  # Reduz o espaçamento entre as barras (de 0 a 1, sendo 0 sem espaçamento)
    height = 600, 
    width = 800
)

fig1.show()

# %% [markdown]
# * Des faixas etarias com maior quantidade de clientes como fica adistribuição por genero.
# #### Distribuiçõa de genero por Idade

# %%
# Verificar tipos de dados
print(df['Idade'].dtype)
print(df_idade['Idade'].dtype)

# Se necessário, converter:
df['Idade'] = df['Idade'].astype(int)
df_idade['Idade'] = df_idade['Idade'].astype(int)
# Out:
# int64
# int64

# %%
# Criar tabela de frequência para Idade e Gênero
frequencia_genero = df.groupby(['Idade', 'Gênero']).size().unstack(fill_value=0)

# Combinar com o DataFrame df_idade
df_idade_por_genero = df_idade.merge(frequencia_genero, on='Idade', how='left')

df_idade_por_genero
# Out:
#     Idade  Quantidade_Clientes  Female  Male
# 0      69                   88      25    63
# 1      57                   87      32    55
# 2      41                   86      19    67
# 3      25                   85      21    64
# 4      49                   84      20    64
# 5      50                   83      30    53
# 6      54                   83      16    67
# 7      27                   83      28    55
# 8      62                   83      32    51
# 9      32                   82      23    59
# 10     19                   81      27    54
# 11     58                   81      27    54
# 12     42                   80      25    55
# 13     43                   79      26    53
# 14     28                   79      26    53
# 15     31                   79      30    49
# 16     37                   77      19    58
# 17     46                   76      30    46
# 18     29                   76      23    53
# 19     68                   75      22    53
# ...

# %%
# Ordenar pela quantidade de clientes e pegar as 10 primeiras idades
top_10_idades = df_idade_por_genero.head(10)

# Calcular a soma total por gênero
distribuicao_por_genero = df_idade_por_genero[['Female', 'Male']].sum().reset_index()
distribuicao_por_genero.columns = ['Gênero', 'Quantidade_Clientes']
distribuicao_por_genero
# Out:
#    Gênero  Quantidade_Clientes
# 0  Female                 1248
# 1    Male                 2652

# %%
# Identificar o índice da fatia com a menor porcentagem
menor_porcent = distribuicao_por_genero['Quantidade_Clientes'].idxmin()

# Criar uma lista para o parâmetro 'pull', destacando a menor fatia
pull_values = [0.05 if i == menor_porcent else 0 for i in range(len(distribuicao_por_genero))]

# Criar o gráfico de pizza usando go.Figure
fig = go.Figure(data=[go.Pie(
    labels=distribuicao_por_genero['Gênero'],
    values=distribuicao_por_genero['Quantidade_Clientes'],
    pull=pull_values  # Destacar a menor fatia
)])

# Adicionar título
fig.update_layout(title_text='Distribuição de Gênero nas Idades mais Frequentes')

# Exibir o gráfico
fig.show()

# %% [markdown]
# #### Quais regiões possuem mais consumidores ativos?

# %%
# Top 10 regiões com consumidores mais ativos
loc = df['Localização']
df_loc = loc.value_counts().reset_index()
df_loc.columns = ['localização', 'Clientes']
df_loc.head(10)
# Out:
#   localização  Clientes
# 0     Montana        96
# 1  California        95
# 2       Idaho        93
# 3    Illinois        92
# 4     Alabama        89
# 5   Minnesota        88
# 6    Nebraska        87
# 7    New York        87
# 8      Nevada        87
# 9    Maryland        86

# %% [markdown]
# #### Existe uma relação entre a localização e o tamanho do item comprado

# %%
# Agrupar dados por Localização e Tamanho e contar as quantidades
tamanho_por_local = df.groupby(['Localização', 'Tamanho']).size().unstack(fill_value=0)

# Exibir a tabela
tamanho_por_local.head(20)
# Out:
# Tamanho       L   M   S  XL
# Localização
# Alabama      23  39  17  10
# Alaska       18  31  14   9
# Arizona      19  23  12  11
# Arkansas     18  40  13   8
# California   23  47  11  14
# Colorado     28  29  12   6
# Connecticut  27  34  10   7
# Delaware     21  42  13  10
# Florida      18  43   3   4
# Georgia      18  42  12   7
# Hawaii       23  29   9   4
# Idaho        21  41  22   9
# Illinois     28  33  24   7
# Indiana      22  28  17  12
# Iowa         12  33  14  10
# Kansas       11  33   8  11
# Kentucky     17  36  19   7
# Louisiana    30  39  10   5
# Maine        21  37  10   9
# Maryland     18  45  11  12

# %%
# Agrupar dados por Localização e Tamanho
tamanho_por_local = df.groupby(['Localização', 'Tamanho']).size().reset_index(name='Quantidade').sort_values(by = 'Quantidade', ascending=False)
tamanho_por_local
# Out:
#    Localização Tamanho  Quantidade
# 17  California       M          47
# 77    Maryland       M          45
# 89   Minnesota       M          43
# 33     Florida       M          43
# 29    Delaware       M          42
# ..         ...     ...         ...
# 91   Minnesota      XL           5
# 71   Louisiana      XL           5
# 35     Florida      XL           4
# 43      Hawaii      XL           4
# 34     Florida       S           3
#
# [200 rows x 3 columns]

# %%
# Agrupar dados por Localização e Tamanho, ordenando pela quantidade
tamanho_por_local = df.groupby(['Localização', 'Tamanho']).size().reset_index(name='Quantidade').sort_values(by='Quantidade', ascending=False)

# Selecionar o tamanho mais frequente
tamanho_mais_frequente = tamanho_por_local.iloc[0]

# Para obter o 'Tamanho' com maior frequência
tamanho_mais_frequente_tamanho = tamanho_mais_frequente['Tamanho']

# Caso queira o tamanho mais frequente por Localização também
tamanho_mais_frequente_localizacao = tamanho_mais_frequente['Localização']

tamanho_mais_frequente_tamanho
# Out:
# 'M'

# %%
# Criar o gráfico de barras com Plotly
fig = px.bar(tamanho_por_local, 
             x='Localização', 
             y='Quantidade', 
             color='Tamanho', 
             title='Distribuição de Tamanhos por Localização',
             labels={'Quantidade': 'Quantidade', 'Localização': 'Localização', 'Tamanho': 'Tamanho'},
             color_discrete_sequence=px.colors.qualitative.Set1)  # Definindo cores distintas

# Exibir o gráfico
fig.show()

# %% [markdown]
# ## Perfil Vendas e Performace

# %% [markdown]
# #### *Quais categorias de produtosgeram geram mais receita?*

# %%
# agrupando dados
receita_por_produto = df.groupby('Categoria')['Valor_da_compra_(USD)'].sum().reset_index().sort_values(by = 'Valor_da_compra_(USD)', ascending = False)

#visuualizando valores
receita_por_produto
# Out:
#      Categoria  Valor_da_compra_(USD)
# 1     Clothing                 104264
# 0  Accessories                  74200
# 2     Footwear                  36093
# 3    Outerwear                  18524

# %%
# plotando resultado
colors = ['gold', 'red', 'blue', 'green']

fig = px.pie(receita_por_produto, 
        values = 'Valor_da_compra_(USD)', 
        names = 'Categoria', 
        title = 'Categorias de produtos que geram mais receita', 
          
        )
fig.update_traces(marker=dict(colors=colors,line=dict(color='rgba(52, 58, 64, 1)', width=2)))

fig.show()

# %% [markdown]
# #### *Qual é o item mais vendido em cada temporada?*

# %%
# # Agrupando dados por temporada, item e valor
# item_mais_vendido_por_temporada  = df.groupby(['Temporada', "Item_comprado"])['Valor_da_compra_(USD)'].sum().reset_index().sort_values(by = 'Valor_da_compra_(USD)', ascending = False)
# Agrupando dados por temporada, item e valor
item_mais_vendido_por_temporada  = df.groupby(['Temporada'])['Valor_da_compra_(USD)'].sum().reset_index().sort_values(by = 'Valor_da_compra_(USD)', ascending = False)

'''
Aqui para selecionar os mais vendidos, como os dados ja estavao em ordem decrecente do maior ao menor,e ao utilizar o metodo first() que selecionar a primeira linha de cada grupo conseguimos obter os valores
'''
item_mais_vendido_por_temporada = item_mais_vendido_por_temporada.groupby('Temporada').first().reset_index()

item_mais_vendido_por_temporada
# Out:
#   Temporada  Valor_da_compra_(USD)
# 0      Fall                  60018
# 1    Spring                  58679
# 2    Summer                  55777
# 3    Winter                  58607

# %%
# Supondo que item_mais_vendido_por_temporada seja o DataFrame
# Criação de gráfico de barras
bar = go.Bar(
    x=item_mais_vendido_por_temporada['Temporada'],
    y=item_mais_vendido_por_temporada['Valor_da_compra_(USD)'],
    name='Valor da Compra',
    marker=dict(color='skyblue'), 
)

# Criação de linha de tendência
line = go.Scatter(
    x=item_mais_vendido_por_temporada['Temporada'],
    y=item_mais_vendido_por_temporada['Valor_da_compra_(USD)'],
    mode='lines+markers',  # Marcadores para os pontos da linha
    name='Linha de Tendência',
    line=dict(color='red', width=2)  # Definindo a cor e o estilo da linha
)

# Configuração do layout do gráfico
layout = go.Layout(
    title='Valor de Compra por Temporada com Linha de Tendência',
    xaxis=dict(title='Temporada'),
    yaxis=dict(title='Valor de Compra (USD)'),
    showlegend=False
)

# Criando o gráfico
fig = go.Figure(data=[bar, line], layout=layout)

# Exibindo o gráfico
fig.show()

# %% [markdown]
# ### *Existem categorias ou itens com baixa avaliação que precisam de atenção?*

# %%
# Agrupar por categoria e item, pegando a maior avaliação
avaliacao_de_categoria_e_item = df.groupby(['Categoria', 'Item_comprado', 'Localização'])['Avaliação_da_avaliação'].min().reset_index()

# Encontrar a maior avaliação por categoria
menor_avaliacao_por_categoria = avaliacao_de_categoria_e_item.groupby('Categoria')['Avaliação_da_avaliação'].min().reset_index()

# Unir os dados para pegar os itens com a maior avaliação por categoria
menores_avaliacoes = pd.merge(avaliacao_de_categoria_e_item, menor_avaliacao_por_categoria, 
                              on=['Categoria', 'Avaliação_da_avaliação'])

menores_avaliacoes
# Out:
#       Categoria Item_comprado     Localização  Avaliação_da_avaliação
# 0   Accessories      Backpack    South Dakota                     2.5
# 1   Accessories          Belt          Alaska                     2.5
# 2   Accessories          Belt     Connecticut                     2.5
# 3   Accessories          Belt          Hawaii                     2.5
# 4   Accessories          Belt   Massachusetts                     2.5
# ..          ...           ...             ...                     ...
# 59    Outerwear        Jacket      California                     2.5
# 60    Outerwear        Jacket         Montana                     2.5
# 61    Outerwear        Jacket  North Carolina                     2.5
# 62    Outerwear        Jacket        Oklahoma                     2.5
# 63    Outerwear        Jacket            Utah                     2.5
#
# [64 rows x 4 columns]

# %%
# Agrupar por categoria e item, pegando a maior avaliação
avaliacao_de_categoria_e_item = df.groupby(['Categoria', 'Item_comprado', 'Localização'])['Avaliação_da_avaliação'].max().reset_index()

# Encontrar a maior avaliação por categoria
maior_avaliacao_por_categoria = avaliacao_de_categoria_e_item.groupby('Categoria')['Avaliação_da_avaliação'].max().reset_index()

# Unir os dados para pegar os itens com a maior avaliação por categoria
maiores_avaliacoes = pd.merge(avaliacao_de_categoria_e_item, maior_avaliacao_por_categoria, 
                              on=['Categoria', 'Avaliação_da_avaliação'])

maiores_avaliacoes
# Out:
#       Categoria Item_comprado    Localização  Avaliação_da_avaliação
# 0   Accessories      Backpack        Georgia                     5.0
# 1   Accessories          Belt         Hawaii                     5.0
# 2   Accessories          Belt        Indiana                     5.0
# 3   Accessories          Belt  Massachusetts                     5.0
# 4   Accessories          Belt  New Hampshire                     5.0
# ..          ...           ...            ...                     ...
# 62    Outerwear          Coat        Montana                     5.0
# 63    Outerwear          Coat           Ohio                     5.0
# 64    Outerwear        Jacket         Alaska                     5.0
# 65    Outerwear        Jacket       Illinois                     5.0
# 66    Outerwear        Jacket     Washington                     5.0
#
# [67 rows x 4 columns]

# %%
# Criando os gráficos Sunburst
fig1 = px.sunburst(menores_avaliacoes, 
                   path=['Categoria', 'Item_comprado', 'Localização'], 
                   values='Avaliação_da_avaliação', 
                   title='Menores Avaliações por Categoria, Item e Localidade')

fig2 = px.sunburst(maiores_avaliacoes, 
                   path=['Categoria', 'Item_comprado', 'Localização'], 
                   values='Avaliação_da_avaliação', 
                   title='Maiores Avaliações por Categoria, Item e Cidade')

# Criando o layout de subplots
fig = make_subplots(
    rows=1, cols=2, 
    specs=[[{'type': 'sunburst'}, {'type': 'sunburst'}]],
    subplot_titles=['Menores Avaliações', 'Maiores Avaliações']
)

# Adicionando os gráficos Sunburst nas subplots
for trace in fig1.data:
    fig.add_trace(trace, row=1, col=1)

for trace in fig2.data:
    fig.add_trace(trace, row=1, col=2)

# Atualizando o layout dos gráficos
fig.update_traces(marker=dict(line=dict(width=1.5, color='black')))  # Adiciona uma borda preta
fig.update_layout(
    # title_text="Comparação das Avaliações por Categoria, Item e Localização",
    margin=dict(t=50, l=50, r=50, b=50),
    showlegend=False  # Remover a legenda para uma apresentação mais limpa
)

# Exibindo o gráfico
fig.show()

# %%
df['Avaliação_da_avaliação'].describe()
# Out:
# count    3900.000000
# mean        3.749949
# std         0.716223
# min         2.500000
# 25%         3.100000
# 50%         3.700000
# 75%         4.400000
# max         5.000000
# Name: Avaliação_da_avaliação, dtype: float64

# %% [markdown]
# ### *Quais cores de produtos são mais populares em cada temporada?*

# %%
# Agrupando por temporada e cor e sabendo as suas quantidades
cores_por_temporada = df.groupby(['Temporada', 'Cor']).size().reset_index(name = 'Quantidade')

# localozando dentro do dataframe as cores mais usadas em cada temporada
cores_por_temporada = cores_por_temporada.loc[cores_por_temporada.groupby('Temporada')['Quantidade'].idxmax()]

cores_por_temporada
# Out:
#    Temporada      Cor  Quantidade
# 11      Fall  Magenta          50
# 38    Spring    Olive          52
# 69    Summer   Silver          59
# 83    Winter    Green          50

# %%
import base64
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Caminho local da imagem
image_path = '/home/black_d/Downloads/Dash_Bourds_Python/td_de_compras/___2_-removebg-preview.png'

# Abrindo e convertendo a imagem em Base64
with open(image_path, 'rb') as img_file:
    encoded_image = base64.b64encode(img_file.read()).decode()

# Definindo as estações e as cores mais populares
temporadas = ['Primavera', 'Verão', 'Outono', 'Inverno']
cores = ['Olive', 'Silver', 'Magenta', 'Green']
quantidades = [50, 60, 70, 40]

# Criando subplots: 1 linha, 4 colunas
fig = make_subplots(
    rows=1, cols=4, 
    specs=[[{'type': 'domain'}, {'type': 'domain'}, {'type': 'domain'}, {'type': 'domain'}]]
)

# Adicionando gráficos de pizza
for i, temporada in enumerate(temporadas):
    fig.add_trace(go.Pie(
        labels=[cores[i]], 
        values=[quantidades[i]], 
        marker=dict(colors=[cores[i]]),
        name=temporada,
        hoverinfo='value',
        textinfo='none'
    ), row=1, col=i+1)

    # Nome da temporada no centro do gráfico
    fig.add_annotation(
        dict(
            text=temporada,
            x=0.130 + 0.25 * i,  
            y=0.5,  
            font=dict(size=20, color="black"),
            showarrow=False,
            xanchor="center",
            yanchor="middle"
        )
    )

# Adicionando a imagem como fundo
fig.update_layout(
    images=[dict(
        source=f"data:image/jpeg;base64,{encoded_image}",
        xref="paper",
        yref="paper",
        x=0.001,
        y=1,
        sizex=1,
        sizey=10,
        xanchor="left",
        yanchor="top",
        layer="below"
    )],
    title_text="Cores Mais Utilizadas por Temporada",
    title_x=0.5,  # centralizando o título
    title_y=0.98,
    title_font=dict(size=20, color="white"),
    paper_bgcolor='#212529',  # Fundo escuro para o gráfico
    plot_bgcolor='#212529',  # Fundo transparente para o gráfico
    margin=dict(t=20, l=20, r=20, b=20)
)

fig.show()

# %% [markdown]
# ### *Qual é o ticket médio das compras por método de pagamento?*

# %%
ticket_medio_por_metodo = df.groupby('Método_de_pagamento')['Valor_da_compra_(USD)'].mean().reset_index()
ticket_medio_por_metodo.rename(columns={'Valor_da_compra_(USD)': 'Ticket_Medio'}, inplace=True)

ticket_medio_por_metodo
# Out:
#   Método_de_pagamento  Ticket_Medio
# 0       Bank Transfer     58.738924
# 1                Cash     59.927469
# 2         Credit Card     61.159483
# 3          Debit Card     58.638231
# 4              PayPal     58.697492
# 5               Venmo     61.241960

# %%
ticket_medio_por_metod = ticket_medio_por_metodo.sort_values(by = 'Ticket_Medio', ascending = False)

fig = px.bar(ticket_medio_por_metod, 
             title = 'ticket médio das compras por método de pagamento',
             x = 'Método_de_pagamento', 
             y = 'Ticket_Medio', 
             color = 'Método_de_pagamento'
             )

fig.show()

# %% [markdown]
# ## Sazonalidade

# %% [markdown]
# ### *Quais categorias de produtos têm maior demanda em cada temporada (ex.: verão, inverno)?*

# %%
# Contagem de itens comprados por Categoria e Temporada
demanda_por_temporada = df.groupby(['Temporada', 'Categoria']).size().reset_index(name='Contagem')

# Encontrar a categoria com maior demanda em cada temporada
categorias_mais_demandadas = demanda_por_temporada.loc[demanda_por_temporada.groupby('Temporada')['Contagem'].idxmax()]

# Resultado
categorias_mais_demandadas
# Out:
#    Temporada Categoria  Contagem
# 1       Fall  Clothing       427
# 5     Spring  Clothing       454
# 9     Summer  Clothing       408
# 13    Winter  Clothing       448

# %% [markdown]
# Uma vez que ja sabemos que a  categoria mais vendida em todas as temporadas e a Clothing.<br>
# Vamos saber dentro desta categoria qual seu produto mais vendido em cada temporada.

# %%
# Filtrar apenas a categoria "Clothing"
clothing_df = df[df['Categoria'] == 'Clothing']

# Contar os produtos mais populares em cada temporada
demanda_clothing_por_temporada = clothing_df.groupby(['Temporada', 'Categoria', 'Item_comprado']).size().reset_index(name='Contagem')

# Encontrar o produto mais comprado em cada temporada
produto_mais_demandado = demanda_clothing_por_temporada.loc[demanda_clothing_por_temporada.groupby('Temporada')['Contagem'].idxmax()]

# Resultado
produto_mais_demandado
# Out:
#    Temporada Categoria Item_comprado  Contagem
# 7       Fall  Clothing         Skirt        46
# 20    Spring  Clothing       Sweater        52
# 26    Summer  Clothing         Pants        50
# 37    Winter  Clothing         Pants        51

# %%
# ordenando por valor da contagem
sort_produto_mais_demandado = produto_mais_demandado.sort_values(by = 'Contagem', ascending = False)

# Criar o gráfico de barras
fig = px.bar(produto_mais_demandado, 
             x='Temporada', 
             y='Contagem', 
             text='Item_comprado',
             color='Item_comprado',
             title='Produtos com Maior Demanda na Categoria Clothing por Temporada',
             labels={'Temporada': 'Estação', 'Item_comprado': 'Produto'})

# Ajustar a exibição do texto nas barras
fig.update_traces(texttemplate='%{text}', textposition='outside')

# Ajustar layout do gráfico
fig.update_layout(showlegend=False, 
                  yaxis=dict(title='Quantidade de Compras', visible = False),
                  xaxis=dict(title='Temporada'),
                  uniformtext_minsize=10, 
                  uniformtext_mode='hide')

# Mostrar o gráfico
fig.show()

# %%
df.head(3)
# Out:
#    ID_do_cliente  Idade Gênero Item_comprado Categoria  Valor_da_compra_(USD)  \
# 0              1     55   Male        Blouse  Clothing                     53
# 1              2     19   Male       Sweater  Clothing                     64
# 2              3     50   Male         Jeans  Clothing                     73
#
#      Localização Tamanho     Cor Temporada  Avaliação_da_avaliação  \
# 0       Kentucky       L    Gray    Winter                     3.1
# 1          Maine       L  Maroon    Winter                     3.1
# 2  Massachusetts       S  Maroon    Spring                     3.1
#
#   Status_da_assinatura Método_de_pagamento  Tipo_de_envio Desconto_aplicado  \
# 0                  Yes         Credit Card        Express               Yes
# 1                  Yes       Bank Transfer        Express               Yes
# 2                  Yes                Cash  Free Shipping               Yes
#
# ...

# %% [markdown]
# ### *Existe uma sazonalidade nas avaliações (ex.: avaliações mais baixas em alguma temporada específica)?*

# %%
# Agrupar para encontrar as menores notas de avaliação em cada temporada
avaliacoes_por_temporada = df.groupby(['Temporada', 'Avaliação_da_avaliação']).size().reset_index(name='Contagem')

# Encontrar as menores notas (Avaliação_da_avaliação) em cada temporada
menores_avaliacoes = avaliacoes_por_temporada.groupby('Temporada')['Avaliação_da_avaliação'].min().reset_index()

# Filtrar as menores avaliações com base no resultado anterior
avaliacoes_baixa_temporada = pd.merge(avaliacoes_por_temporada, menores_avaliacoes, on=['Temporada', 'Avaliação_da_avaliação'])

avaliacoes_baixa_temporada
# Out:
#   Temporada  Avaliação_da_avaliação  Contagem
# 0      Fall                     2.5        14
# 1    Spring                     2.5        17
# 2    Summer                     2.5        14
# 3    Winter                     2.5        21

# %%
# Dados
temporadas = ['Fall', 'Spring', 'Summer', 'Winter']
contagens = [14, 17, 14, 21]

# Gráfico de cascata
fig = go.Figure(go.Waterfall(
    x=temporadas,  # Eixo x com as temporadas
    y=contagens,   # Contagens para cada temporada
    textposition="inside",
    text=[str(v) for v in contagens],  # Valores dentro das barras
    decreasing={"marker": {"color": "lightblue"}},  # Cor das barras
    increasing={"marker": {"color": "lightgreen"}},
    totals={"marker": {"color": "red"}}  # Cor do total (se necessário)
))

# Layout do gráfico
fig.update_layout(
    yaxis = dict(visible = False), 
    title="Distribuição de Avaliações Baixas (Nota 2.5) por Temporada",
    xaxis_title="Temporada",
    showlegend=False  # Remove a legenda
)

fig.show()

# %% [markdown]
# ## *Métodos de pagamento e descontos*

# %%
# * Qual é o método de pagamento mais utilizado pelos clientes?
# * Clientes que utilizam descontos têm maior frequência de compras?
# * Existe alguma preferência por método de pagamento dependendo da localização ou categoria do produto?

# %% [markdown]
# #### *Qual é o método de pagamento mais utilizado pelos clientes?*

# %%
pagamentos = df['Método_de_pagamento']
df_metodo_pagamento = pagamentos.value_counts().sort_values(ascending=False).reset_index(name = 'Quantidade')

df_metodo_pagamento
# Out:
#   Método_de_pagamento  Quantidade
# 0         Credit Card         696
# 1               Venmo         653
# 2                Cash         648
# 3              PayPal         638
# 4          Debit Card         633
# 5       Bank Transfer         632

# %%
sort_df_metodo_pagamento = df_metodo_pagamento.sort_values(by = 'Quantidade')
fig = px.bar(df_metodo_pagamento,
             y = 'Quantidade',
             x = 'Método_de_pagamento', 
             title = 'Métodos de pagamentos mais utilizados', 
            #  orientation = 'h', 
            #  text = 'Quantidade'
             )
fig.update_layout(yaxis_title = '')
fig.show()

# %% [markdown]
# #### *Clientes que utilizam descontos têm maior frequência de compras?*

# %%
# Agrupando os dados para analizar a frequencia de clientes que usan e nao usam desconto
df_frequencia_de_compras_por_desconto = df.groupby([df['Desconto_aplicado'], df['Frequência_de_compras']]).size().reset_index(name = 'Quantidade')


df_frequencia_de_compras_por_desconto
# Out:
#    Desconto_aplicado Frequência_de_compras  Quantidade
# 0                 No              Annually         334
# 1                 No             Bi-Weekly         321
# 2                 No        Every 3 Months         326
# 3                 No           Fortnightly         299
# 4                 No               Monthly         316
# 5                 No             Quarterly         322
# 6                 No                Weekly         305
# 7                Yes              Annually         238
# 8                Yes             Bi-Weekly         226
# 9                Yes        Every 3 Months         258
# 10               Yes           Fortnightly         243
# 11               Yes               Monthly         237
# 12               Yes             Quarterly         241
# 13               Yes                Weekly         234

# %%
# separando somente os clientes que não utilizan desconto
nao_utilizao_desconto = df_frequencia_de_compras_por_desconto.loc[df_frequencia_de_compras_por_desconto['Desconto_aplicado'] == 'No']

# ordenando em ordem decrecente pela coluna de 'Quantidade'
# nao_utilizao_desconto = nao_utilizao_desconto.sort_values(by = 'Quantidade', ascending = False)

# # salvando tabela
# nao_utilizao_desconto.to_csv('/home/black_d/Downloads/Dash_Bourds_Python/tendências_de_compras/DataFrames/nao_utilizao_desconto.csv', index=False)

nao_utilizao_desconto
# Out:
#   Desconto_aplicado Frequência_de_compras  Quantidade
# 0                No              Annually         334
# 1                No             Bi-Weekly         321
# 2                No        Every 3 Months         326
# 3                No           Fortnightly         299
# 4                No               Monthly         316
# 5                No             Quarterly         322
# 6                No                Weekly         305

# %%
# separando somente os clientes que utilizan desconto
utilizao_desconto = df_frequencia_de_compras_por_desconto.loc[df_frequencia_de_compras_por_desconto['Desconto_aplicado'] == 'Yes']

# ordenando em ordem decrecente pela coluna de 'Quantidade'
# utilizao_desconto = utilizao_desconto.sort_values(by = 'Quantidade', ascending = False)

# salvando tabela
# utilizao_desconto.to_csv('/home/black_d/Downloads/Dash_Bourds_Python/tendências_de_compras/DataFrames/utilizao_desconto.csv', index=False)

utilizao_desconto
# Out:
#    Desconto_aplicado Frequência_de_compras  Quantidade
# 7                Yes              Annually         238
# 8                Yes             Bi-Weekly         226
# 9                Yes        Every 3 Months         258
# 10               Yes           Fortnightly         243
# 11               Yes               Monthly         237
# 12               Yes             Quarterly         241
# 13               Yes                Weekly         234

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Criação do gráfico único
fig = go.Figure()

# Gráfico 1: Clientes com Desconto
fig.add_trace(
    go.Scatter(
        x=utilizao_desconto["Frequência_de_compras"],
        y=utilizao_desconto["Quantidade"],
        mode='lines+markers+text',  # Adiciona linha, pontos e texto
        line=dict(color="green"),  # Cor da linha
        name="Com Desconto",  # Nome da série
        text=utilizao_desconto["Quantidade"],  # Adiciona os valores como texto
        textposition="top center",  # Posiciona os textos no topo central
        hoverinfo="text+x+y",  # Exibe as informações no hover (texto, eixo X e eixo Y)
    )
)

# Gráfico 2: Clientes sem Desconto
fig.add_trace(
    go.Scatter(
        x=nao_utilizao_desconto["Frequência_de_compras"],
        y=nao_utilizao_desconto["Quantidade"],
        mode='lines+markers+text',  # Adiciona linha, pontos e texto
        line=dict(color="red"),  # Cor da linha
        name="Sem Desconto",  # Nome da série
        text=nao_utilizao_desconto["Quantidade"],  # Adiciona os valores como texto
        textposition="top center",  # Posiciona os textos no topo central
        hoverinfo="text+x+y",  # Exibe as informações no hover (texto, eixo X e eixo Y)
    )
)

# Layout do gráfico
fig.update_layout(
    title_text="Frequência de Compras: Clientes com e sem Desconto",  # Título geral do gráfico
    title_x=0.5,
    title_y=0.95,  # Ajusta a posição vertical do título
    showlegend=True,  # Exibe a legenda
    height=700,   # Dimensões do gráfico
)

# Ajusta os eixos X para melhor visualização
fig.update_xaxes(title_text="Frequência de Compras", tickangle=45)

# Ajusta os eixos Y
fig.update_yaxes(title_text="Quantidade")

# Mostrar gráfico
fig.show()

# %%
# Criação dos subplots lado a lado
fig = make_subplots(
    rows=1, cols=2,  # 1 linha e 2 colunas
    subplot_titles=("Clientes com Desconto", "Clientes sem Desconto")  # Títulos de cada gráfico
)

# Gráfico 1: Clientes com Desconto
fig.add_trace(
    go.Bar(
        x=utilizao_desconto["Frequência_de_compras"],
        y=utilizao_desconto["Quantidade"],
        text=utilizao_desconto["Quantidade"],  # Adiciona os valores como texto
        textposition="auto",  # Posiciona automaticamente o texto
        marker_color="green"  # Cor das barras
    ),
    row=1, col=1  # Define a posição no subplot
)

# Gráfico 2: Clientes sem Desconto
fig.add_trace(
    go.Bar(
        x=nao_utilizao_desconto["Frequência_de_compras"],
        y=nao_utilizao_desconto["Quantidade"],
        text=nao_utilizao_desconto["Quantidade"],  # Adiciona os valores como texto
        textposition="auto",  # Posiciona automaticamente o texto
        marker_color="red"  # Cor das barras
    ),
    row=1, col=2  # Define a posição no subplot
)

# Layout do gráfico
fig.update_layout(
    title_text="Frequência de Compras: Clientes com e sem Desconto",  # Título geral do gráfico
     title_x=0.5,
    title_y=0.95,  # Ajusta a posição vertical do título
    showlegend=False,  # Remove a legenda
    height=500,   # Dimensões do gráfico
   
)

# Ajusta os eixos X para melhor visualização
fig.update_xaxes(title_text="Frequência de Compras", tickangle=45, row=1, col=1)
fig.update_xaxes(title_text="Frequência de Compras", tickangle=45, row=1, col=2)

# Ajusta os eixos Y
fig.update_yaxes(title_text="Quantidade", row=1, col=1,  visible = False)
fig.update_yaxes(title_text="", row=1, col=2, visible = False)

# Mostrar gráfico
fig.show()

# %% [markdown]
# #### *Existe alguma preferência por método de pagamento dependendo da localização ou categoria do produto?*

# %%
# Agrupar por Localização e Método de Pagamento e contar a quantidade
metodo_pagamento_por_localizacao = df.groupby(['Localização', 'Método_de_pagamento']).size().reset_index(name = 'Quantidade')

# Exibir o resultado
metodo_pagamento_por_localizacao.head()
# Out:
#   Localização Método_de_pagamento  Quantidade
# 0     Alabama       Bank Transfer          22
# 1     Alabama                Cash          12
# 2     Alabama         Credit Card          14
# 3     Alabama          Debit Card          10
# 4     Alabama              PayPal          15

# %%
# Agrupar por Categoria do Produto e Método de Pagamento e contar a quantidade
metodo_pagamento_por_categoria = df.groupby(['Categoria', 'Método_de_pagamento']).size().reset_index(name='Quantidade')

# Exibir o resultado
metodo_pagamento_por_categoria.head()
# Out:
#      Categoria Método_de_pagamento  Quantidade
# 0  Accessories       Bank Transfer         198
# 1  Accessories                Cash         200
# 2  Accessories         Credit Card         245
# 3  Accessories          Debit Card         195
# 4  Accessories              PayPal         199

# %%
sort_metodo_pagamento_por_localizacao = metodo_pagamento_por_localizacao.sort_values(by = 'Quantidade', ascending=True)

# plot
fig_localizacao = px.bar(sort_metodo_pagamento_por_localizacao, 
                         x='Localização', 
                         y='Quantidade', 
                         color='Método_de_pagamento', 
                         title="Método de Pagamento por Localização",
                        #  orientation='h'
                         )

fig_localizacao.update_layout(height = 600, 
                              width = 850, 
                              showlegend = True)
fig_localizacao.show()

# %%
sort_metodo_pagamento_por_categoria = metodo_pagamento_por_categoria.sort_values(by = 'Quantidade', ascending = False)

fig_categoria = px.bar(sort_metodo_pagamento_por_categoria, 
                       x='Categoria', 
                       y='Quantidade', 
                       color='Método_de_pagamento', 
                       title="Método de Pagamento por Categoria de Produto", 
                    #    text = 'Quantidade',
                       )

# Configurar para mostrar as barras lado a lado
fig_categoria.update_layout(
    barmode='group',
    yaxis=dict(showticklabels=True))  # Remover rótulos e ticks do eixo Y

fig_categoria.show()

# %%
df['Categoria'].unique()
# Out:
# array(['Clothing', 'Footwear', 'Outerwear', 'Accessories'], dtype=object)

# %%
# Criando o gráfico de linhas
fig = px.line(tamanho_por_temporada, 
              x='Temporada', 
              y='Valor_da_compra_(USD)', 
              color='Tamanho', 
              markers=True, 
              title='Relação das Vendas por Tamanho e Temporadas',
              labels={'Valor_da_compra_(USD)': 'Quantidade de Compras', 'Temporada': 'Temporada'},
              height=500)

# Ajustando a exibição dos valores corretos nos pontos
for trace in fig.data:
    trace.update(mode='lines+markers+text', 
                 text=trace.y,  # Usa os valores Y corretos para cada linha
                 textposition='top center')

# Exibir o gráfico
fig.show()

# %%
fig = px.treemap(tamanho_por_temporada, 
                 path=['Temporada', 'Tamanho'], 
                 values='Valor_da_compra_(USD)', 
                 title="Proporção das Vendas por Tamanho e Temporada",
                 color='Valor_da_compra_(USD)', 
                 color_continuous_scale='Blues', 
                #  text_auto=True
                 )
# Exibir os valores dentro dos retângulos
# fig.update_traces(textinfo="label+value")

fig.update_layout(showlegend=False, 
                  legend=dict(
            itemsizing='constant',  # Ajusta o comportamento da legenda
            itemclick='toggleothers',  # Define como a legenda se comporta ao clicar
            itemdoubleclick='toggle',  # Define o que acontece com duplo clique
            traceorder='normal',  # Controla a ordem de exibição das legendas
            bordercolor="White",  # Altere a cor da borda, caso necessário
            borderwidth=0,  # Remove borda para a legenda
            orientation='h',  # Se necessário, mudar a orientação da legenda
            font=dict(color='white')  # Cor da fonte da legenda
        ),)
fig.show()
